# %% [markdown]
# # Exploration (optional)
#
# This notebook is optional. The main project is runnable via the CLI pipeline and Streamlit dashboard.
#
# - Generate the synthetic dataset
# - Inspect trends
# - Sanity-check margins and cash runway

# %%
import pandas as pd
from src.model import generate_saas_actuals

df = generate_saas_actuals(months=48, seed=7)
df.head()

# %%
df[['month','customers','revenue','gross_margin_pct','opex','operating_income','ending_cash']].tail()
